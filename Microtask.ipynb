# %% [markdown]
# # Language-agnostic modeling of quality of Wikipedia articles
#
# This notebook provides a tutorial for how to explore the dataset from language-agnostic feature values and quality scores of Wikipedia articles. It has 3 stages:
# 1. Accessing and extending a sample of the dataset
# 2. Visualizing features values and qualities scores over time
# 3. Future Analyses

# %% [markdown]
# ## 1. Accessing to the data
#
# The dataset of language-agnostic feature values and quality scores of Wikipedia articles available on [Zenodo](https://zenodo.org/records/10495081) is too large to handle with a Jupyter notebook. For that reason, we have prepared a sample with the revisions of English Wikipedia articles maintained by [WikiProject Climate change](https://en.wikipedia.org/wiki/Wikipedia:WikiProject_Climate_change) with the following columns:
# - wiki_db: Wikipedia language edition ('enwiki' in this sample).
# - page_id: Id of the page (in the corresponding Wikipedia language edition).
# - revision_id: Id of the revision (in the corresponding Wikipedia language edition).
# - page_length:  Number of bytes of the revision.
# - num_refs:  Number of references of the revision.
# - num_wikilinks: Number of wikilinks of the revision.
# - num_categories: Number of categories of the revision.
# - num_media: Number of media files of the revision.
# - num_headings: Number of sections of the revision.
# - item_id: Id of the page in Wikidata.
# - pred_qual: Predicted quality score between 0 and 1.

# %%
# TODO: add other libraries here as necessary
import pandas as pd

# %%
# Read the zipped CSV
df_revisions = pd.read_csv('https://public-paws.wmcloud.org/User:Pablo%20(WMF)/outreachy/round28/features_scores_climatechange_2022.csv.zip')
df_revisions
# Out:
#         wiki_db   page_id  revision_id    revision_timestamp  page_length  \
# 0        enwiki    348869    366664976  2010-06-07T22:45:20Z        10464
# 1        enwiki    348869    251114181  2008-11-11T15:34:55Z         4049
# 2        enwiki    348869    712041311  2016-03-26T15:07:18Z        20701
# 3        enwiki    348869    341876534  2010-02-04T12:02:16Z        10100
# 4        enwiki    348869    519730962  2012-10-25T09:56:12Z        17858
# ...         ...       ...          ...                   ...          ...
# 1456207  enwiki  66790245   1069533455  2022-02-02T19:41:20Z        42178
# 1456208  enwiki  66790245   1007245703  2021-02-17T04:02:02Z          744
# 1456209  enwiki  66790245   1041821278  2021-09-01T18:18:01Z         5728
# 1456210  enwiki  66790245   1055285832  2021-11-15T00:29:52Z        34922
# 1456211  enwiki  66790245   1083221740  2022-04-17T18:49:10Z        40452
#
#          num_refs  num_wikilinks  num_categories  num_media  num_headings  \
# 0              11             66               4          2             7
# 1               0             41               4          2             3
# 2              28             84               4          2            10
# 3              11             61               4          2             7
# 4              21             93               4          2             9
# ...           ...            ...             ...        ...           ...
# 1456207        81            118               4          2            14
# 1456208         1              2               0          0             0
# 1456209         9             19               4          0             5
# 1456210        80            115               4          1            14
# 1456211        80            119               4          2            14
#
#             item_id  pred_qual
# 0          Q1137345   0.557963
# 1          Q1137345   0.397999
# 2          Q1137345   0.696191
# 3          Q1137345   0.554477
# 4          Q1137345   0.654836
# ...             ...        ...
# 1456207  Q105549782   0.797312
# 1456208  Q105549782   0.139069
# 1456209  Q105549782   0.401310
# 1456210  Q105549782   0.770978
# 1456211  Q105549782   0.800184
#
# [1456212 rows x 12 columns]

# %%
# As mentioned above, pages are English Wikipedia articles maintained by WikiProject Climate change. 
# The id and title of these pages, together with their quality class and importance class can be extracted with the following Quarry query:
# https://quarry.wmcloud.org/query/52210
df_pages = pd.read_csv('https://quarry.wmcloud.org/query/52210/result/latest/0/csv')
df_pages
# Out:
#        page_id                            page_title quality_class  \
# 0           39                                Albedo             B
# 1          627                           Agriculture            GA
# 2          903                           Arable_land             C
# 3         1365                               Ammonia             B
# 4         3201  Attribution_of_recent_climate_change             B
# ...        ...                                   ...           ...
# 3812  73428116                  Anne_Therese_Gennari         Start
# 3813  73464356                   Christopher_Magadza             C
# 3814  73540566                       Britney_Schmidt             C
# 3815  73569052     Rainwater_harvesting_in_the_Sahel             C
# 3816  73608388                         Judy_Lawrence          Stub
#
#      importance_class
# 0                High
# 1                 Low
# 2                 Low
# 3                 Low
# 4                High
# ...               ...
# 3812              Low
# 3813              Low
# 3814              Low
# 3815              Low
# 3816          Unknown
#
# [3817 rows x 4 columns]

# %%
# Both dataframes can be merged to extend metadata of the revisions samples
df_revisions.merge(df_pages, on='page_id')
# Out:
#         wiki_db   page_id  revision_id    revision_timestamp  page_length  \
# 0        enwiki    348869    366664976  2010-06-07T22:45:20Z        10464
# 1        enwiki    348869    251114181  2008-11-11T15:34:55Z         4049
# 2        enwiki    348869    712041311  2016-03-26T15:07:18Z        20701
# 3        enwiki    348869    341876534  2010-02-04T12:02:16Z        10100
# 4        enwiki    348869    519730962  2012-10-25T09:56:12Z        17858
# ...         ...       ...          ...                   ...          ...
# 1426996  enwiki  66790245   1069533455  2022-02-02T19:41:20Z        42178
# 1426997  enwiki  66790245   1007245703  2021-02-17T04:02:02Z          744
# 1426998  enwiki  66790245   1041821278  2021-09-01T18:18:01Z         5728
# 1426999  enwiki  66790245   1055285832  2021-11-15T00:29:52Z        34922
# 1427000  enwiki  66790245   1083221740  2022-04-17T18:49:10Z        40452
#
#          num_refs  num_wikilinks  num_categories  num_media  num_headings  \
# 0              11             66               4          2             7
# 1               0             41               4          2             3
# 2              28             84               4          2            10
# 3              11             61               4          2             7
# 4              21             93               4          2             9
# ...           ...            ...             ...        ...           ...
# 1426996        81            118               4          2            14
# 1426997         1              2               0          0             0
# 1426998         9             19               4          0             5
# 1426999        80            115               4          1            14
# 1427000        80            119               4          2            14
#
#             item_id  pred_qual                  page_title quality_class  \
# 0          Q1137345   0.557963  North_Atlantic_oscillation         Start
# 1          Q1137345   0.397999  North_Atlantic_oscillation         Start
# 2          Q1137345   0.696191  North_Atlantic_oscillation         Start
# 3          Q1137345   0.554477  North_Atlantic_oscillation         Start
# 4          Q1137345   0.654836  North_Atlantic_oscillation         Start
# ...             ...        ...                         ...           ...
# 1426996  Q105549782   0.797312      Build_Back_Better_Plan             C
# 1426997  Q105549782   0.139069      Build_Back_Better_Plan             C
# 1426998  Q105549782   0.401310      Build_Back_Better_Plan             C
# 1426999  Q105549782   0.770978      Build_Back_Better_Plan             C
# 1427000  Q105549782   0.800184      Build_Back_Better_Plan             C
#
#         importance_class
# 0                Unknown
# 1                Unknown
# 2                Unknown
# 3                Unknown
# 4                Unknown
# ...                  ...
# 1426996              Mid
# 1426997              Mid
# 1426998              Mid
# 1426999              Mid
# 1427000              Mid
#
# [1427001 rows x 15 columns]

# %%
# !pip install mwviews 
from mwviews.api import PageviewsClient
# Out:
# Requirement already satisfied: mwviews in /srv/paws/lib/python3.10/site-packages (0.2.1)
# Requirement already satisfied: requests in /srv/paws/lib/python3.10/site-packages (from mwviews) (2.31.0)
# Requirement already satisfied: more-itertools in /srv/paws/lib/python3.10/site-packages (from mwviews) (10.2.0)
# Requirement already satisfied: docopt in /srv/paws/lib/python3.10/site-packages (from mwviews) (0.6.2)
# Requirement already satisfied: mwcli in /srv/paws/lib/python3.10/site-packages (from mwviews) (0.0.3)
# Requirement already satisfied: mwapi in /srv/paws/lib/python3.10/site-packages (from mwviews) (0.6.1)
# Requirement already satisfied: aiohttp in /srv/paws/lib/python3.10/site-packages (from mwapi->mwviews) (3.9.3)
# Requirement already satisfied: para in /srv/paws/lib/python3.10/site-packages (from mwcli->mwviews) (0.0.8)
# Requirement already satisfied: mwxml in /srv/paws/lib/python3.10/site-packages (from mwcli->mwviews) (0.3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /srv/paws/lib/python3.10/site-packages (from requests->mwviews) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /srv/paws/lib/python3.10/site-packages (from requests->mwviews) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/paws/lib/python3.10/site-packages (from requests->mwviews) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/paws/lib/python3.10/site-packages (from requests->mwviews) (2024.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /srv/paws/lib/python3.10/site-packages (from aiohttp->mwapi->mwviews) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /srv/paws/lib/python3.10/site-packages (from aiohttp->mwapi->mwviews) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /srv/paws/lib/python3.10/site-packages (from aiohttp->mwapi->mwviews) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /srv/paws/lib/python3.10/site-packages (from aiohttp->mwapi->mwviews) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /srv/paws/lib/python3.10/site-packages (from aiohttp->mwapi->mwviews) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /srv/paws/lib/python3.10/site-packages (from aiohttp->mwapi->mwviews) (4.0.3)
# Requirement already satisfied: jsonschema>=2.5.1 in /srv/paws/lib/python3.10/site-packages (from mwxml->mwcli->mwviews) (4.21.1)
# Requirement already satisfied: mwtypes>=0.3.0 in /srv/paws/lib/python3.10/site-packages (from mwxml->mwcli->mwviews) (0.3.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /srv/paws/lib/python3.10/site-packages (from jsonschema>=2.5.1->mwxml->mwcli->mwviews) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /srv/paws/lib/python3.10/site-packages (from jsonschema>=2.5.1->mwxml->mwcli->mwviews) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /srv/paws/lib/python3.10/site-packages (from jsonschema>=2.5.1->mwxml->mwcli->mwviews) (0.18.0)
# Requirement already satisfied: jsonable>=0.3.0 in /srv/paws/lib/python3.10/site-packages (from mwtypes>=0.3.0->mwxml->mwcli->mwviews) (0.3.1)

# %%
# TODO: For any article, you need to use the API to gather pageviews count
# in the time period each revision was made.
# mwviews documentation: https://github.com/mediawiki-utilities/python-mwviews
# user_agent helps identify the request if there's an issue and is best practice
tutorial_label = 'PAWS Language-agnostic quality modeling tutorial (mwapi)'
# NOTE: it is best practice to include a contact email in user agents
# generally this is private information though so do not change it to yours
# if you are working in the PAWS environment or adding to a Github repo
# for Outreachy, you can leave this as Pablo's email or switch it to your Mediawiki username
# e.g., Pablo (WMF) for https://www.mediawiki.org/wiki/User:Pablo_(WMF)
contact_email = 'paragon@wikimedia.org'
p = PageviewsClient(user_agent=f'<{contact_email}> {tutorial_label}')
# See below an example for monthly pageviews of two given articles in 2022
p.article_views('en.wikipedia', ['Albedo', 'Agriculture'], granularity='monthly', start='20220101', end='20221231')
# Out:
# defaultdict(dict,
#             {datetime.datetime(2022, 11, 1, 0, 0): {'Albedo': 35815,
#               'Agriculture': 147939},
#              datetime.datetime(2022, 1, 1, 0, 0): {'Albedo': 33276,
#               'Agriculture': 129619},
#              datetime.datetime(2022, 3, 1, 0, 0): {'Albedo': 33142,
#               'Agriculture': 163182},
#              datetime.datetime(2022, 5, 1, 0, 0): {'Albedo': 31365,
#               'Agriculture': 122209},
#              datetime.datetime(2022, 6, 1, 0, 0): {'Albedo': 26119,
#               'Agriculture': 99250},
#              datetime.datetime(2022, 10, 1, 0, 0): {'Albedo': 35853,
#               'Agriculture': 135306},
#              datetime.datetime(2022, 9, 1, 0, 0): {'Albedo': 34701,
#               'Agriculture': 149693},
#              datetime.datetime(2022, 12, 1, 0, 0): {'Albedo': 27722,
#               'Agriculture': 114116},
#              datetime.datetime(2022, 4, 1, 0, 0): {'Albedo': 35430,
#               'Agriculture': 126763},
#              datetime.datetime(2022, 8, 1, 0, 0): {'Albedo': 27766,
#               'Agriculture': 112030},
#              datetime.datetime(2022, 7, 1, 0, 0): {'Albedo': 30038,
#               'Agriculture': 93480},
#              datetime.datetime(2022, 2, 1, 0, 0): {'Albedo': 33159,
#               'Agriculture': 176946}})

# %% [markdown]
# ## 2. Visualizing features values and qualities scores over time
#
# Here we want to explore the evolution of individual articles and the sample of Climate change articles  by visualizing feature values and quality scores over time. For this type of data, plots like the following would make sense, showing the predicted quality scores of the latest revision up to a given year of each English Wikipedia article (the darkness of the color corresponds to the time dimension, the darker the more recent).
#
# ![image1](./enwiki_boxplot.png)
#
# Choose a more fine-grained time granularity than yearly (e.g., monthly, weekly, daily, hourly) and create data visualizations of the features value and scores (page_length, num_refs, num_wikilinks, num_categories, num_media, num_headings, pred_qual). Write your thoughts on the trade-offs between longer vs. shorter granularities and how this affects the visualization.

# %%
# TODO: Build the data analysis and visualization per instructions above

# %% [markdown]
# Then create data visualizations using different types of charts and proposing approaches to filtering and aggregating data.

# %%
# TODO: Build the data analysis and visualization per instructions above

# %% [markdown]
# ## 3. Future Analyses

# %%
# TODO: Describe what additional patterns you might want to explore and visualize in the data (and why). You don't know have to know how to do the analyses.
